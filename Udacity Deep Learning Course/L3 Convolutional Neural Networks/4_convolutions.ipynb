# %% [markdown]
# Deep Learning
# =============
#
# Assignment 4
# ------------
#
# Previously in `2_fullyconnected.ipynb` and `3_regularization.ipynb`, we trained fully connected networks to classify [notMNIST](http://yaroslavvb.blogspot.com/2011/09/notmnist-dataset.html) characters.
#
# The goal of this assignment is make the neural network convolutional.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import numpy as np
import tensorflow as tf
from six.moves import cPickle as pickle
from six.moves import range

# %%
pickle_file = 'notMNIST.pickle'

with open(pickle_file, 'rb') as f:
  save = pickle.load(f)
  train_dataset = save['train_dataset']
  train_labels = save['train_labels']
  valid_dataset = save['valid_dataset']
  valid_labels = save['valid_labels']
  test_dataset = save['test_dataset']
  test_labels = save['test_labels']
  del save  # hint to help gc free up memory
  print('Training set', train_dataset.shape, train_labels.shape)
  print('Validation set', valid_dataset.shape, valid_labels.shape)
  print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28) (200000,)
# Validation set (10000, 28, 28) (10000,)
# Test set (10000, 28, 28) (10000,)

# %% [markdown]
# Reformat into a TensorFlow-friendly shape:
# - convolutions need the image data formatted as a cube (width by height by #channels)
# - labels as float 1-hot encodings.

# %%
image_size = 28
num_labels = 10
num_channels = 1 # grayscale

import numpy as np

def reformat(dataset, labels):
  dataset = dataset.reshape(
    (-1, image_size, image_size, num_channels)).astype(np.float32)
  labels = (np.arange(num_labels) == labels[:,None]).astype(np.float32)
  return dataset, labels
train_dataset, train_labels = reformat(train_dataset, train_labels)
valid_dataset, valid_labels = reformat(valid_dataset, valid_labels)
test_dataset, test_labels = reformat(test_dataset, test_labels)
print('Training set', train_dataset.shape, train_labels.shape)
print('Validation set', valid_dataset.shape, valid_labels.shape)
print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28, 1) (200000, 10)
# Validation set (10000, 28, 28, 1) (10000, 10)
# Test set (10000, 28, 28, 1) (10000, 10)

# %%
def accuracy(predictions, labels):
  return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1))
          / predictions.shape[0])

# %% [markdown]
# Let's build a small network with two convolutional layers, followed by one fully connected layer. Convolutional networks are more expensive computationally, so we'll limit its depth and number of fully connected nodes.

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    # 注意卷积层的参数，conv2d的第三个参数是stride，分别对应卷积核在四个维度上的步进，本代码中是[1,2,2,1]
    conv = tf.nn.conv2d(data, layer1_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    conv = tf.nn.conv2d(hidden, layer2_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    shape = hidden.get_shape().as_list()
    reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 3.413498
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.1%
# Minibatch loss at step 50: 1.627888
# Minibatch accuracy: 43.8%
# Validation accuracy: 61.6%
# Minibatch loss at step 100: 1.081186
# Minibatch accuracy: 62.5%
# Validation accuracy: 67.3%
# Minibatch loss at step 150: 1.068735
# Minibatch accuracy: 81.2%
# Validation accuracy: 76.2%
# Minibatch loss at step 200: 1.384268
# Minibatch accuracy: 75.0%
# Validation accuracy: 77.0%
# Minibatch loss at step 250: 1.094036
# Minibatch accuracy: 62.5%
# Validation accuracy: 79.0%
# Minibatch loss at step 300: 0.508051
# Minibatch accuracy: 87.5%
# Validation accuracy: 78.2%
# Minibatch loss at step 350: 0.261284
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.7%
# Minibatch loss at step 400: 0.494845
# Minibatch accuracy: 87.5%
# Validation accuracy: 76.9%
# Minibatch loss at step 450: 0.302305
# Minibatch accuracy: 93.8%
# Validation accuracy: 80.4%
# Minibatch loss at step 500: 0.313163
# Minibatch accuracy: 93.8%
# Validation accuracy: 81.4%
# Minibatch loss at step 550: 0.868205
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.3%
# Minibatch loss at step 600: 0.890850
# Minibatch accuracy: 62.5%
# Validation accuracy: 81.3%
# Minibatch loss at step 650: 0.230254
# Minibatch accuracy: 93.8%
# Validation accuracy: 81.8%
# Minibatch loss at step 700: 0.365824
# Minibatch accuracy: 93.8%
# Validation accuracy: 81.5%
# Minibatch loss at step 750: 0.455996
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.6%
# Minibatch loss at step 800: 0.769325
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.3%
# Minibatch loss at step 850: 0.680910
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.9%
# Minibatch loss at step 900: 0.706612
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.9%
# Minibatch loss at step 950: 0.662107
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.7%
# Minibatch loss at step 1000: 0.774242
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.1%
# Test accuracy: 89.1%

# %% [markdown]
# ---
# Problem 1
# ---------
#
# The convolutional model above uses convolutions with stride 2 to reduce the dimensionality. Replace the strides by a max pooling operation (`nn.max_pool()`) of stride 2 and kernel size 2.
#
# ---

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
    pool = tf.nn.max_pool(conv, [1,2,2,1],[1,2,2,1],padding='SAME')
    hidden = tf.nn.relu(pool + layer1_biases)
    conv = tf.nn.conv2d(hidden, layer2_weights, [1, 1, 1, 1], padding='SAME')
    pool = tf.nn.max_pool(conv, [1,2,2,1],[1,2,2,1],padding='SAME')
    hidden = tf.nn.relu(pool + layer2_biases)
    shape = hidden.get_shape().as_list()
    reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 3.442513
# Minibatch accuracy: 12.5%
# Validation accuracy: 10.0%
# Minibatch loss at step 50: 2.070124
# Minibatch accuracy: 25.0%
# Validation accuracy: 32.6%
# Minibatch loss at step 100: 1.269171
# Minibatch accuracy: 43.8%
# Validation accuracy: 62.1%
# Minibatch loss at step 150: 0.890867
# Minibatch accuracy: 87.5%
# Validation accuracy: 75.7%
# Minibatch loss at step 200: 1.507453
# Minibatch accuracy: 75.0%
# Validation accuracy: 75.0%
# Minibatch loss at step 250: 1.058928
# Minibatch accuracy: 56.2%
# Validation accuracy: 79.3%
# Minibatch loss at step 300: 0.433374
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.7%
# Minibatch loss at step 350: 0.411410
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.4%
# Minibatch loss at step 400: 0.161996
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.1%
# Minibatch loss at step 450: 0.223186
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.4%
# Minibatch loss at step 500: 0.343942
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.3%
# Minibatch loss at step 550: 0.837896
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.2%
# Minibatch loss at step 600: 0.653896
# Minibatch accuracy: 68.8%
# Validation accuracy: 83.7%
# Minibatch loss at step 650: 0.202746
# Minibatch accuracy: 93.8%
# Validation accuracy: 83.9%
# Minibatch loss at step 700: 0.263447
# Minibatch accuracy: 93.8%
# Validation accuracy: 83.5%
# Minibatch loss at step 750: 0.541411
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.4%
# Minibatch loss at step 800: 0.659047
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.6%
# Minibatch loss at step 850: 0.635949
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.5%
# Minibatch loss at step 900: 0.460210
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.4%
# Minibatch loss at step 950: 0.695512
# Minibatch accuracy: 68.8%
# Validation accuracy: 84.0%
# Minibatch loss at step 1000: 0.511719
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.3%
# Test accuracy: 90.9%

# %% [markdown]
# ---
# Problem 2
# ---------
#
# Try to get the best performance you can using a convolutional net. Look for example at the classic [LeNet5](http://yann.lecun.com/exdb/lenet/) architecture, adding Dropout, and/or adding learning rate decay.
#
# ---

# %%
batch_size = 200
patch_size = 5
depth = 16
num_hidden = 128


num_steps = 5001

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  #global_step = tf.Variable(0)
  #learning_rate = tf.train.exponential_decay(0.08, global_step, 200, 0.98)
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data,train=False):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    hidden = tf.nn.max_pool(hidden, [1,2,2,1],[1,2,2,1],padding='SAME')
    conv = tf.nn.conv2d(hidden, layer2_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    hidden = tf.nn.max_pool(hidden, [1,2,2,1],[1,2,2,1],padding='SAME')
    if train:
        hidden = tf.nn.dropout(hidden, 0.5)
    shape = hidden.get_shape().as_list()
    reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    if train:
        hidden = tf.nn.dropout(hidden, 0.5)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))

  for w in (layer1_weights, layer2_weights,layer3_weights, layer4_weights):
    loss += 5e-4 * tf.nn.l2_loss(w)
    
  # Optimizer.
  optimizer = tf.train.AdamOptimizer().minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 6.207124
# Minibatch accuracy: 9.0%
# Validation accuracy: 10.1%
# Minibatch loss at step 50: 1.449489
# Minibatch accuracy: 67.0%
# Validation accuracy: 65.4%
# Minibatch loss at step 100: 0.957821
# Minibatch accuracy: 80.5%
# Validation accuracy: 79.2%
# Minibatch loss at step 150: 0.988963
# Minibatch accuracy: 80.0%
# Validation accuracy: 80.5%
# Minibatch loss at step 200: 0.753688
# Minibatch accuracy: 84.0%
# Validation accuracy: 81.7%
# Minibatch loss at step 250: 0.823176
# Minibatch accuracy: 81.5%
# Validation accuracy: 83.6%
# Minibatch loss at step 300: 0.655829
# Minibatch accuracy: 85.5%
# Validation accuracy: 84.6%
# Minibatch loss at step 350: 0.785861
# Minibatch accuracy: 84.0%
# Validation accuracy: 85.2%
# Minibatch loss at step 400: 0.749135
# Minibatch accuracy: 84.5%
# Validation accuracy: 85.6%
# Minibatch loss at step 450: 0.590675
# Minibatch accuracy: 91.5%
# Validation accuracy: 85.9%
# Minibatch loss at step 500: 0.475825
# Minibatch accuracy: 91.5%
# Validation accuracy: 85.6%
# Minibatch loss at step 550: 0.857169
# Minibatch accuracy: 79.5%
# Validation accuracy: 86.5%
# Minibatch loss at step 600: 0.590533
# Minibatch accuracy: 87.0%
# Validation accuracy: 87.0%
# Minibatch loss at step 650: 0.655104
# Minibatch accuracy: 85.0%
# Validation accuracy: 87.0%
# Minibatch loss at step 700: 0.687745
# Minibatch accuracy: 84.0%
# Validation accuracy: 87.1%
# Minibatch loss at step 750: 0.555159
# Minibatch accuracy: 88.5%
# Validation accuracy: 87.3%
# Minibatch loss at step 800: 0.546425
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.0%
# Minibatch loss at step 850: 0.617954
# Minibatch accuracy: 86.5%
# Validation accuracy: 87.7%
# Minibatch loss at step 900: 0.510241
# Minibatch accuracy: 89.0%
# Validation accuracy: 88.2%
# Minibatch loss at step 950: 0.674793
# Minibatch accuracy: 84.5%
# Validation accuracy: 88.2%
# Minibatch loss at step 1000: 0.593148
# Minibatch accuracy: 85.0%
# Validation accuracy: 88.5%
# Minibatch loss at step 1050: 0.530457
# Minibatch accuracy: 86.5%
# Validation accuracy: 88.0%
# Minibatch loss at step 1100: 0.568563
# Minibatch accuracy: 89.0%
# Validation accuracy: 88.7%
# Minibatch loss at step 1150: 0.540810
# Minibatch accuracy: 90.5%
# Validation accuracy: 88.6%
# Minibatch loss at step 1200: 0.496958
# Minibatch accuracy: 88.5%
# Validation accuracy: 88.8%
# Minibatch loss at step 1250: 0.485731
# Minibatch accuracy: 89.0%
# Validation accuracy: 88.8%
# Minibatch loss at step 1300: 0.540504
# Minibatch accuracy: 85.5%
# Validation accuracy: 88.8%
# Minibatch loss at step 1350: 0.590845
# Minibatch accuracy: 86.0%
# Validation accuracy: 88.5%
# Minibatch loss at step 1400: 0.484076
# Minibatch accuracy: 90.0%
# Validation accuracy: 88.9%
# Minibatch loss at step 1450: 0.424413
# Minibatch accuracy: 92.0%
# Validation accuracy: 88.9%
# Minibatch loss at step 1500: 0.412599
# Minibatch accuracy: 92.0%
# Validation accuracy: 89.0%
# Minibatch loss at step 1550: 0.381780
# Minibatch accuracy: 91.5%
# Validation accuracy: 89.2%
# Minibatch loss at step 1600: 0.525748
# Minibatch accuracy: 89.0%
# Validation accuracy: 89.2%
# Minibatch loss at step 1650: 0.522737
# Minibatch accuracy: 89.5%
# Validation accuracy: 89.4%
# Minibatch loss at step 1700: 0.398646
# Minibatch accuracy: 92.5%
# Validation accuracy: 89.3%
# Minibatch loss at step 1750: 0.381034
# Minibatch accuracy: 94.5%
# Validation accuracy: 89.4%
# Minibatch loss at step 1800: 0.388102
# Minibatch accuracy: 92.5%
# Validation accuracy: 89.4%
# Minibatch loss at step 1850: 0.401545
# Minibatch accuracy: 91.5%
# Validation accuracy: 89.5%
# Minibatch loss at step 1900: 0.560838
# Minibatch accuracy: 88.0%
# Validation accuracy: 89.6%
# Minibatch loss at step 1950: 0.481820
# Minibatch accuracy: 90.5%
# Validation accuracy: 89.5%
# Minibatch loss at step 2000: 0.484599
# Minibatch accuracy: 89.5%
# Validation accuracy: 89.8%
# Minibatch loss at step 2050: 0.420785
# Minibatch accuracy: 90.5%
# Validation accuracy: 89.4%
# Minibatch loss at step 2100: 0.382415
# Minibatch accuracy: 90.0%
# Validation accuracy: 90.0%
# Minibatch loss at step 2150: 0.426401
# Minibatch accuracy: 90.5%
# Validation accuracy: 90.0%
# Minibatch loss at step 2200: 0.466298
# Minibatch accuracy: 89.5%
# Validation accuracy: 89.8%
# Minibatch loss at step 2250: 0.349641
# Minibatch accuracy: 92.5%
# Validation accuracy: 90.1%
# Minibatch loss at step 2300: 0.231670
# Minibatch accuracy: 95.5%
# Validation accuracy: 89.7%
# Minibatch loss at step 2350: 0.377124
# Minibatch accuracy: 93.0%
# Validation accuracy: 90.0%
# Minibatch loss at step 2400: 0.421896
# Minibatch accuracy: 91.0%
# Validation accuracy: 90.0%
# Minibatch loss at step 2450: 0.390280
# Minibatch accuracy: 91.0%
# Validation accuracy: 90.2%
# Minibatch loss at step 2500: 0.463243
# Minibatch accuracy: 86.5%
# Validation accuracy: 90.2%
# Minibatch loss at step 2550: 0.555112
# Minibatch accuracy: 86.5%
# Validation accuracy: 90.1%
# Minibatch loss at step 2600: 0.413116
# Minibatch accuracy: 90.0%
# Validation accuracy: 90.1%
# Minibatch loss at step 2650: 0.461769
# Minibatch accuracy: 88.0%
# Validation accuracy: 89.9%
# Minibatch loss at step 2700: 0.432461
# Minibatch accuracy: 90.0%
# Validation accuracy: 90.1%
# Minibatch loss at step 2750: 0.457221
# Minibatch accuracy: 88.0%
# Validation accuracy: 90.3%
# Minibatch loss at step 2800: 0.414842
# Minibatch accuracy: 90.5%
# Validation accuracy: 90.4%
# Minibatch loss at step 2850: 0.315475
# Minibatch accuracy: 93.5%
# Validation accuracy: 90.2%
# Minibatch loss at step 2900: 0.405873
# Minibatch accuracy: 90.0%
# Validation accuracy: 90.6%
# Minibatch loss at step 2950: 0.393136
# Minibatch accuracy: 91.0%
# Validation accuracy: 89.9%
# Minibatch loss at step 3000: 0.418049
# Minibatch accuracy: 89.0%
# Validation accuracy: 90.2%
# Minibatch loss at step 3050: 0.338139
# Minibatch accuracy: 93.0%
# Validation accuracy: 90.2%
# Minibatch loss at step 3100: 0.326241
# Minibatch accuracy: 93.0%
# Validation accuracy: 90.4%
# Minibatch loss at step 3150: 0.386943
# Minibatch accuracy: 88.5%
# Validation accuracy: 90.5%
# Minibatch loss at step 3200: 0.315237
# Minibatch accuracy: 92.5%
# Validation accuracy: 90.6%
# Minibatch loss at step 3250: 0.361978
# Minibatch accuracy: 91.0%
# Validation accuracy: 90.5%
# Minibatch loss at step 3300: 0.414940
# Minibatch accuracy: 91.0%
# Validation accuracy: 90.2%
# Minibatch loss at step 3350: 0.429867
# Minibatch accuracy: 90.0%
# Validation accuracy: 90.4%
# Minibatch loss at step 3400: 0.270453
# Minibatch accuracy: 95.0%
# Validation accuracy: 90.5%
# Minibatch loss at step 3450: 0.358142
# Minibatch accuracy: 90.5%
# Validation accuracy: 90.4%
# Minibatch loss at step 3500: 0.213076
# Minibatch accuracy: 96.5%
# Validation accuracy: 90.5%
# Minibatch loss at step 3550: 0.438206
# Minibatch accuracy: 90.0%
# Validation accuracy: 90.6%
# Minibatch loss at step 3600: 0.340625
# Minibatch accuracy: 92.0%
# Validation accuracy: 90.5%
# Minibatch loss at step 3650: 0.378649
# Minibatch accuracy: 92.5%
# Validation accuracy: 90.4%
# Minibatch loss at step 3700: 0.403597
# Minibatch accuracy: 90.0%
# Validation accuracy: 90.6%
# Minibatch loss at step 3750: 0.477459
# Minibatch accuracy: 89.5%
# Validation accuracy: 90.8%
# Minibatch loss at step 3800: 0.392009
# Minibatch accuracy: 91.0%
# Validation accuracy: 90.7%
# Minibatch loss at step 3850: 0.299043
# Minibatch accuracy: 92.5%
# Validation accuracy: 90.5%
# Minibatch loss at step 3900: 0.394198
# Minibatch accuracy: 89.5%
# Validation accuracy: 90.9%
# Minibatch loss at step 3950: 0.401138
# Minibatch accuracy: 89.5%
# Validation accuracy: 90.3%
# Minibatch loss at step 4000: 0.349482
# Minibatch accuracy: 91.0%
# Validation accuracy: 90.6%
# Minibatch loss at step 4050: 0.270033
# Minibatch accuracy: 94.5%
# Validation accuracy: 90.4%
# Minibatch loss at step 4100: 0.263294
# Minibatch accuracy: 94.5%
# Validation accuracy: 90.7%
# Minibatch loss at step 4150: 0.382516
# Minibatch accuracy: 90.5%
# Validation accuracy: 90.8%
# Minibatch loss at step 4200: 0.334415
# Minibatch accuracy: 91.0%
# Validation accuracy: 90.7%
# Minibatch loss at step 4250: 0.385943
# Minibatch accuracy: 89.0%
# Validation accuracy: 90.9%
# Minibatch loss at step 4300: 0.411686
# Minibatch accuracy: 90.5%
# Validation accuracy: 90.7%
# Minibatch loss at step 4350: 0.399992
# Minibatch accuracy: 90.0%
# Validation accuracy: 90.7%
# Minibatch loss at step 4400: 0.411793
# Minibatch accuracy: 88.5%
# Validation accuracy: 90.8%
# Minibatch loss at step 4450: 0.304922
# Minibatch accuracy: 94.0%
# Validation accuracy: 90.6%
# Minibatch loss at step 4500: 0.292290
# Minibatch accuracy: 92.0%
# Validation accuracy: 90.9%
# Minibatch loss at step 4550: 0.301057
# Minibatch accuracy: 93.0%
# Validation accuracy: 91.0%
# Minibatch loss at step 4600: 0.321566
# Minibatch accuracy: 92.5%
# Validation accuracy: 90.7%
# Minibatch loss at step 4650: 0.396044
# Minibatch accuracy: 91.0%
# Validation accuracy: 90.8%
# Minibatch loss at step 4700: 0.352832
# Minibatch accuracy: 91.0%
# Validation accuracy: 91.1%
# Minibatch loss at step 4750: 0.281300
# Minibatch accuracy: 93.0%
# Validation accuracy: 91.2%
# Minibatch loss at step 4800: 0.289966
# Minibatch accuracy: 93.0%
# Validation accuracy: 90.9%
# Minibatch loss at step 4850: 0.483611
# Minibatch accuracy: 84.5%
# Validation accuracy: 90.8%
# Minibatch loss at step 4900: 0.385280
# Minibatch accuracy: 90.5%
# Validation accuracy: 91.1%
# Minibatch loss at step 4950: 0.344519
# Minibatch accuracy: 91.0%
# Validation accuracy: 90.3%
# Minibatch loss at step 5000: 0.252158
# Minibatch accuracy: 94.5%
# Validation accuracy: 91.0%
# Test accuracy: 95.9%
